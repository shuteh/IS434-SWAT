# %%
from geopy.geocoders import GoogleV3
import pandas as pd
import numpy as np
import requests

# %%
data = pd.read_csv('resultslatlon.csv', encoding='utf8')
data
# Out:
#      Unnamed: 0   Organization Name   latitude   longitude
# 0             0  Loadshare Networks  12.936921   77.624945
# 1             1            Locus.sh  51.514339   -0.108747
# 2             2            Locus.sh  51.229505    6.776593
# 3             3            Locus.sh  19.118577   72.890366
# 4             4            Locus.sh  12.925613   77.636771
# ..          ...                 ...        ...         ...
# 258         260                 IPR  35.701638  139.415824
# 259         261   AND Systems Japan  34.678568  135.501034
# 260         262          Ard Sosiyo  35.695999  139.770134
# 261         263            Fullback  34.961280  136.627700
# 262         264     Tensei Data Net  36.063049  136.193709
#
# [263 rows x 4 columns]

# %%
def reverse_geo(lat,lon):
#     locations = geolocator.reverse(x)
#     country = locations.country
#     return country
    api_key='AIzaSyAGut0nPIu24ydb1IU1QgYkvMwQF6lZC_0'

    base = "https://maps.googleapis.com/maps/api/geocode/json?"
    params = "latlng={lat},{lon}".format(
        lat=lat,
        lon=lon,
    )
    geocode_url = "{base}{params}".format(base=base, params=params)
    if api_key is not None:
        geocode_url = geocode_url + "&key={}".format(api_key)
    response = requests.get(geocode_url).json()
    result = response['results'][0]['formatted_address']
    return result

# %%
print(reverse_geo(12.936921,77.624945))
# Out:
# 509, 6th Cross Rd, near to Koramangala club, 6th Block, Koramangala, Bengaluru, Karnataka 560095, India

# %%
data['formatted_address'] = data.apply(lambda x: reverse_geo(x['latitude'], x['longitude']), axis=1)

# %%
data
# Out:
#      Unnamed: 0   Organization Name   latitude   longitude  \
# 0             0  Loadshare Networks  12.936921   77.624945
# 1             1            Locus.sh  51.514339   -0.108747
# 2             2            Locus.sh  51.229505    6.776593
# 3             3            Locus.sh  19.118577   72.890366
# 4             4            Locus.sh  12.925613   77.636771
# ..          ...                 ...        ...         ...
# 258         260                 IPR  35.701638  139.415824
# 259         261   AND Systems Japan  34.678568  135.501034
# 260         262          Ard Sosiyo  35.695999  139.770134
# 261         263            Fullback  34.961280  136.627700
# 262         264     Tensei Data Net  36.063049  136.193709
#
#                                      formatted_address
# 0    509, 6th Cross Rd, near to Koramangala club, 6...
# 1         4th Floor, 167 Fleet St, London EC4A 2EA, UK
# 2    Heinrich-Heine-Allee 1, 40213 Düsseldorf, Germany
# ...

# %%
def split_get_country(x):
    splitted_add = x.split(',')
    return splitted_add[-1]

# %%
data['country'] = data.apply(lambda x: split_get_country(x['formatted_address']), axis=1)

# %%
data
# Out:
#      Unnamed: 0   Organization Name   latitude   longitude  \
# 0             0  Loadshare Networks  12.936921   77.624945
# 1             1            Locus.sh  51.514339   -0.108747
# 2             2            Locus.sh  51.229505    6.776593
# 3             3            Locus.sh  19.118577   72.890366
# 4             4            Locus.sh  12.925613   77.636771
# ..          ...                 ...        ...         ...
# 258         260                 IPR  35.701638  139.415824
# 259         261   AND Systems Japan  34.678568  135.501034
# 260         262          Ard Sosiyo  35.695999  139.770134
# 261         263            Fullback  34.961280  136.627700
# 262         264     Tensei Data Net  36.063049  136.193709
#
#                                      formatted_address  \
# 0    509, 6th Cross Rd, near to Koramangala club, 6...
# 1         4th Floor, 167 Fleet St, London EC4A 2EA, UK
# 2    Heinrich-Heine-Allee 1, 40213 Düsseldorf, Germany
# ...

# %%
pd.DataFrame(data).to_csv('resultslatloncountry.csv', encoding='utf8')
