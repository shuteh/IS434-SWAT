# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('resultslatloncountry.csv', encoding='utf8')
data
# Out:
#      Unnamed: 0  Unnamed: 0.1   Organization Name   latitude   longitude  \
# 0             0             0  Loadshare Networks  12.936921   77.624945
# 1             1             1            Locus.sh  51.514339   -0.108747
# 2             2             2            Locus.sh  51.229505    6.776593
# 3             3             3            Locus.sh  19.118577   72.890366
# 4             4             4            Locus.sh  12.925613   77.636771
# ..          ...           ...                 ...        ...         ...
# 258         258           260                 IPR  35.701638  139.415824
# 259         259           261   AND Systems Japan  34.678568  135.501034
# 260         260           262          Ard Sosiyo  35.695999  139.770134
# 261         261           263            Fullback  34.961280  136.627700
# 262         262           264     Tensei Data Net  36.063049  136.193709
#
#                                      formatted_address   country
# ...

# %%
data['country'] = data.apply(lambda x: x['country'].strip(), axis=1)

# %%
data
# Out:
#      Unnamed: 0  Unnamed: 0.1   Organization Name   latitude   longitude  \
# 0             0             0  Loadshare Networks  12.936921   77.624945
# 1             1             1            Locus.sh  51.514339   -0.108747
# 2             2             2            Locus.sh  51.229505    6.776593
# 3             3             3            Locus.sh  19.118577   72.890366
# 4             4             4            Locus.sh  12.925613   77.636771
# ..          ...           ...                 ...        ...         ...
# 258         258           260                 IPR  35.701638  139.415824
# 259         259           261   AND Systems Japan  34.678568  135.501034
# 260         260           262          Ard Sosiyo  35.695999  139.770134
# 261         261           263            Fullback  34.961280  136.627700
# 262         262           264     Tensei Data Net  36.063049  136.193709
#
#                                      formatted_address  country
# ...

# %%
pd.DataFrame(data).to_csv('cleanedfinal.csv', encoding='utf8')
